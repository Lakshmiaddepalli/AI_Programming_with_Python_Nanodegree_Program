# %% [markdown]
# # Classifying Fashion-MNIST
#
# Now it's your turn to build and train a neural network. You'll be using the [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist), a drop-in replacement for the MNIST dataset. MNIST is actually quite trivial with neural networks where you can easily achieve better than 97% accuracy. Fashion-MNIST is a set of 28x28 greyscale images of clothes. It's more complex than MNIST, so it's a better representation of the actual performance of your network, and a better representation of datasets you'll use in the real world.
#
# <img src='assets/fashion-mnist-sprite.png' width=500px>
#
# In this notebook, you'll build your own neural network. For the most part, you could just copy and paste the code from Part 3, but you wouldn't be learning. It's important for you to write the code yourself and get it to work. Feel free to consult the previous notebook though as you work through this.
#
# First off, let's load the dataset through torchvision.

# %%
import torch
from torchvision import datasets, transforms
import helper

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# Download and load the training data
trainset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here we can see one of the images.

# %%
image, label = next(iter(trainloader))
helper.imshow(image[0,:]);

# %% [markdown]
# With the data loaded, it's time to import the necessary packages.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import time

from collections import OrderedDict

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

import helper

# %% [markdown]
# ## Building the network
#
# Here you should define your network. As with MNIST, each image is 28x28 which is a total of 784 pixels, and there are 10 classes. You should include at least one hidden layer. We suggest you use ReLU activations for the layers and to return the logits from the forward pass. It's up to you how many layers you add and the size of those layers.

# %%
# TODO: Define your network architecture here
# Hyperparameters for our network
input_size = 784
hidden_sizes = [128, 64,32,16]
output_size = 10

# Build a feed-forward network
model = nn.Sequential(OrderedDict([
                      ('fc1', nn.Linear(input_size, hidden_sizes[0])),
                      ('relu1', nn.ReLU()),
                      ('fc2', nn.Linear(hidden_sizes[0], hidden_sizes[1])),
                      ('relu2', nn.ReLU()),
                      ('fc3', nn.Linear(hidden_sizes[1], hidden_sizes[2])),
                      ('relu3', nn.ReLU()),
                      ('fc4', nn.Linear(hidden_sizes[2], hidden_sizes[3])),
                      ('relu4', nn.ReLU()),
                      ('logits', nn.Linear(hidden_sizes[3], output_size))]))

# %% [markdown]
# # Train the network
#
# Now you should create your network and train it. First you'll want to define [the criterion](http://pytorch.org/docs/master/nn.html#loss-functions) ( something like `nn.CrossEntropyLoss`) and [the optimizer](http://pytorch.org/docs/master/optim.html) (typically `optim.SGD` or `optim.Adam`).
#
# Then write the training code. Remember the training pass is a fairly straightforward process:
#
# * Make a forward pass through the network to get the logits
# * Use the logits to calculate the loss
# * Perform a backward pass through the network with `loss.backward()` to calculate the gradients
# * Take a step with the optimizer to update the weights
#
# By adjusting the hyperparameters (hidden units, learning rate, etc), you should be able to get the training loss below 0.4.

# %%
# TODO: Create the network, define the criterion and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# TODO: Train the network here

epochs = 20
print_every = 40
steps = 0
for e in range(epochs):
    running_loss = 0
    for images, labels in iter(trainloader):
        steps += 1
        # Flatten MNIST images into a 784 long vector
        images.resize_(images.size()[0], 784)
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        output = model.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            print("Epoch: {}/{}... ".format(e+1, epochs),
                  "Loss: {:.4f}".format(running_loss/print_every))
            
            running_loss = 0
# Out:
# Epoch: 1/20...  Loss: 2.3092
# Epoch: 1/20...  Loss: 2.3083
# Epoch: 1/20...  Loss: 2.3041
# Epoch: 1/20...  Loss: 2.3047
# Epoch: 1/20...  Loss: 2.3027
# Epoch: 1/20...  Loss: 2.2973
# Epoch: 1/20...  Loss: 2.2927
# Epoch: 1/20...  Loss: 2.2920
# Epoch: 1/20...  Loss: 2.2886
# Epoch: 1/20...  Loss: 2.2846
# Epoch: 1/20...  Loss: 2.2777
# Epoch: 1/20...  Loss: 2.2716
# Epoch: 1/20...  Loss: 2.2651
# Epoch: 1/20...  Loss: 2.2501
# Epoch: 1/20...  Loss: 2.2377
# Epoch: 1/20...  Loss: 2.2151
# Epoch: 1/20...  Loss: 2.1833
# Epoch: 1/20...  Loss: 2.1418
# Epoch: 1/20...  Loss: 2.0715
# Epoch: 1/20...  Loss: 1.9648
# Epoch: 1/20...  Loss: 1.8237
# Epoch: 1/20...  Loss: 1.6351
# Epoch: 1/20...  Loss: 1.4489
# Epoch: 2/20...  Loss: 0.6955
# Epoch: 2/20...  Loss: 1.1744
# Epoch: 2/20...  Loss: 1.1116
# Epoch: 2/20...  Loss: 1.0572
# Epoch: 2/20...  Loss: 1.0016
# Epoch: 2/20...  Loss: 0.9512
# Epoch: 2/20...  Loss: 0.9153
# Epoch: 2/20...  Loss: 0.9055
# Epoch: 2/20...  Loss: 0.8587
# Epoch: 2/20...  Loss: 0.8227
# Epoch: 2/20...  Loss: 0.7962
# Epoch: 2/20...  Loss: 0.7714
# Epoch: 2/20...  Loss: 0.7765
# Epoch: 2/20...  Loss: 0.7313
# Epoch: 2/20...  Loss: 0.7170
# Epoch: 2/20...  Loss: 0.7126
# Epoch: 2/20...  Loss: 0.7110
# Epoch: 2/20...  Loss: 0.7386
# Epoch: 2/20...  Loss: 0.7136
# Epoch: 2/20...  Loss: 0.7134
# Epoch: 2/20...  Loss: 0.7261
# Epoch: 2/20...  Loss: 0.7062
# Epoch: 2/20...  Loss: 0.7236
# Epoch: 3/20...  Loss: 0.0615
# Epoch: 3/20...  Loss: 0.6965
# Epoch: 3/20...  Loss: 0.6876
# Epoch: 3/20...  Loss: 0.6873
# Epoch: 3/20...  Loss: 0.6939
# Epoch: 3/20...  Loss: 0.6643
# Epoch: 3/20...  Loss: 0.6874
# Epoch: 3/20...  Loss: 0.6790
# Epoch: 3/20...  Loss: 0.6185
# Epoch: 3/20...  Loss: 0.6424
# Epoch: 3/20...  Loss: 0.6304
# Epoch: 3/20...  Loss: 0.6299
# Epoch: 3/20...  Loss: 0.6271
# Epoch: 3/20...  Loss: 0.6239
# Epoch: 3/20...  Loss: 0.6391
# Epoch: 3/20...  Loss: 0.6176
# Epoch: 3/20...  Loss: 0.6390
# Epoch: 3/20...  Loss: 0.6059
# Epoch: 3/20...  Loss: 0.5843
# Epoch: 3/20...  Loss: 0.5843
# Epoch: 3/20...  Loss: 0.5863
# Epoch: 3/20...  Loss: 0.5931
# Epoch: 3/20...  Loss: 0.5959
# Epoch: 3/20...  Loss: 0.6239
# Epoch: 4/20...  Loss: 0.3744
# Epoch: 4/20...  Loss: 0.5994
# Epoch: 4/20...  Loss: 0.5893
# Epoch: 4/20...  Loss: 0.5836
# Epoch: 4/20...  Loss: 0.5930
# Epoch: 4/20...  Loss: 0.5915
# Epoch: 4/20...  Loss: 0.5793
# Epoch: 4/20...  Loss: 0.5799
# Epoch: 4/20...  Loss: 0.5799
# Epoch: 4/20...  Loss: 0.5527
# Epoch: 4/20...  Loss: 0.5330
# Epoch: 4/20...  Loss: 0.5824
# Epoch: 4/20...  Loss: 0.5640
# Epoch: 4/20...  Loss: 0.5694
# Epoch: 4/20...  Loss: 0.5582
# Epoch: 4/20...  Loss: 0.5281
# Epoch: 4/20...  Loss: 0.5437
# Epoch: 4/20...  Loss: 0.5148
# Epoch: 4/20...  Loss: 0.5288
# Epoch: 4/20...  Loss: 0.5869
# Epoch: 4/20...  Loss: 0.5396
# Epoch: 4/20...  Loss: 0.5071
# Epoch: 4/20...  Loss: 0.5370
# Epoch: 5/20...  Loss: 0.1038
# Epoch: 5/20...  Loss: 0.5516
# Epoch: 5/20...  Loss: 0.5382
# Epoch: 5/20...  Loss: 0.5174
# Epoch: 5/20...  Loss: 0.5264
# Epoch: 5/20...  Loss: 0.5250
# Epoch: 5/20...  Loss: 0.5231
# Epoch: 5/20...  Loss: 0.5272
# Epoch: 5/20...  Loss: 0.4843
# Epoch: 5/20...  Loss: 0.5290
# Epoch: 5/20...  Loss: 0.4930
# Epoch: 5/20...  Loss: 0.5264
# Epoch: 5/20...  Loss: 0.5126
# Epoch: 5/20...  Loss: 0.5122
# Epoch: 5/20...  Loss: 0.4921
# Epoch: 5/20...  Loss: 0.4914
# Epoch: 5/20...  Loss: 0.5082
# Epoch: 5/20...  Loss: 0.5233
# Epoch: 5/20...  Loss: 0.4863
# Epoch: 5/20...  Loss: 0.4972
# Epoch: 5/20...  Loss: 0.5205
# Epoch: 5/20...  Loss: 0.5275
# Epoch: 5/20...  Loss: 0.5143
# Epoch: 5/20...  Loss: 0.4862
# Epoch: 6/20...  Loss: 0.3504
# Epoch: 6/20...  Loss: 0.4568
# Epoch: 6/20...  Loss: 0.4858
# Epoch: 6/20...  Loss: 0.5070
# Epoch: 6/20...  Loss: 0.5021
# Epoch: 6/20...  Loss: 0.5038
# Epoch: 6/20...  Loss: 0.4782
# Epoch: 6/20...  Loss: 0.4967
# Epoch: 6/20...  Loss: 0.4876
# Epoch: 6/20...  Loss: 0.4853
# Epoch: 6/20...  Loss: 0.4753
# Epoch: 6/20...  Loss: 0.4774
# Epoch: 6/20...  Loss: 0.4852
# Epoch: 6/20...  Loss: 0.4707
# Epoch: 6/20...  Loss: 0.4698
# Epoch: 6/20...  Loss: 0.4934
# Epoch: 6/20...  Loss: 0.4597
# Epoch: 6/20...  Loss: 0.4367
# Epoch: 6/20...  Loss: 0.4729
# Epoch: 6/20...  Loss: 0.4459
# Epoch: 6/20...  Loss: 0.4831
# Epoch: 6/20...  Loss: 0.4510
# Epoch: 6/20...  Loss: 0.4402
# Epoch: 7/20...  Loss: 0.1483
# Epoch: 7/20...  Loss: 0.4436
# Epoch: 7/20...  Loss: 0.4648
# Epoch: 7/20...  Loss: 0.4356
# Epoch: 7/20...  Loss: 0.4536
# Epoch: 7/20...  Loss: 0.4357
# Epoch: 7/20...  Loss: 0.4540
# Epoch: 7/20...  Loss: 0.4637
# Epoch: 7/20...  Loss: 0.4475
# Epoch: 7/20...  Loss: 0.4259
# Epoch: 7/20...  Loss: 0.4251
# Epoch: 7/20...  Loss: 0.4668
# Epoch: 7/20...  Loss: 0.4163
# Epoch: 7/20...  Loss: 0.4383
# Epoch: 7/20...  Loss: 0.4767
# Epoch: 7/20...  Loss: 0.4786
# Epoch: 7/20...  Loss: 0.4115
# Epoch: 7/20...  Loss: 0.4561
# Epoch: 7/20...  Loss: 0.4543
# Epoch: 7/20...  Loss: 0.4602
# Epoch: 7/20...  Loss: 0.4180
# Epoch: 7/20...  Loss: 0.4300
# Epoch: 7/20...  Loss: 0.4394
# Epoch: 7/20...  Loss: 0.4585
# Epoch: 8/20...  Loss: 0.3570
# Epoch: 8/20...  Loss: 0.4259
# Epoch: 8/20...  Loss: 0.4172
# Epoch: 8/20...  Loss: 0.4075
# Epoch: 8/20...  Loss: 0.4491
# Epoch: 8/20...  Loss: 0.4154
# Epoch: 8/20...  Loss: 0.4187
# Epoch: 8/20...  Loss: 0.4544
# Epoch: 8/20...  Loss: 0.4035
# Epoch: 8/20...  Loss: 0.4463
# Epoch: 8/20...  Loss: 0.4294
# Epoch: 8/20...  Loss: 0.4067
# Epoch: 8/20...  Loss: 0.4184
# Epoch: 8/20...  Loss: 0.4174
# Epoch: 8/20...  Loss: 0.4265
# Epoch: 8/20...  Loss: 0.4398
# Epoch: 8/20...  Loss: 0.4335
# Epoch: 8/20...  Loss: 0.4152
# Epoch: 8/20...  Loss: 0.4388
# Epoch: 8/20...  Loss: 0.3998
# Epoch: 8/20...  Loss: 0.4380
# Epoch: 8/20...  Loss: 0.4004
# Epoch: 8/20...  Loss: 0.4332
# Epoch: 9/20...  Loss: 0.1758
# Epoch: 9/20...  Loss: 0.4092
# Epoch: 9/20...  Loss: 0.4162
# Epoch: 9/20...  Loss: 0.4188
# Epoch: 9/20...  Loss: 0.4067
# Epoch: 9/20...  Loss: 0.3919
# Epoch: 9/20...  Loss: 0.4336
# Epoch: 9/20...  Loss: 0.3834
# Epoch: 9/20...  Loss: 0.4041
# Epoch: 9/20...  Loss: 0.3896
# Epoch: 9/20...  Loss: 0.4000
# Epoch: 9/20...  Loss: 0.4134
# Epoch: 9/20...  Loss: 0.4008
# Epoch: 9/20...  Loss: 0.3893
# Epoch: 9/20...  Loss: 0.4009
# Epoch: 9/20...  Loss: 0.3823
# Epoch: 9/20...  Loss: 0.4047
# Epoch: 9/20...  Loss: 0.4217
# Epoch: 9/20...  Loss: 0.4394
# Epoch: 9/20...  Loss: 0.4038
# Epoch: 9/20...  Loss: 0.3909
# Epoch: 9/20...  Loss: 0.4141
# Epoch: 9/20...  Loss: 0.3734
# Epoch: 9/20...  Loss: 0.4015
# Epoch: 10/20...  Loss: 0.3773
# Epoch: 10/20...  Loss: 0.3798
# Epoch: 10/20...  Loss: 0.4042
# Epoch: 10/20...  Loss: 0.3571
# Epoch: 10/20...  Loss: 0.3805
# Epoch: 10/20...  Loss: 0.4007
# Epoch: 10/20...  Loss: 0.4068
# Epoch: 10/20...  Loss: 0.3676
# Epoch: 10/20...  Loss: 0.3899
# Epoch: 10/20...  Loss: 0.3732
# Epoch: 10/20...  Loss: 0.3826
# Epoch: 10/20...  Loss: 0.3932
# Epoch: 10/20...  Loss: 0.3963
# Epoch: 10/20...  Loss: 0.3963
# Epoch: 10/20...  Loss: 0.3580
# Epoch: 10/20...  Loss: 0.3624
# Epoch: 10/20...  Loss: 0.4111
# Epoch: 10/20...  Loss: 0.3739
# Epoch: 10/20...  Loss: 0.3915
# Epoch: 10/20...  Loss: 0.4158
# Epoch: 10/20...  Loss: 0.3911
# Epoch: 10/20...  Loss: 0.3670
# Epoch: 10/20...  Loss: 0.3853
# Epoch: 11/20...  Loss: 0.2022
# Epoch: 11/20...  Loss: 0.3297
# Epoch: 11/20...  Loss: 0.3830
# Epoch: 11/20...  Loss: 0.3654
# Epoch: 11/20...  Loss: 0.3814
# Epoch: 11/20...  Loss: 0.3684
# Epoch: 11/20...  Loss: 0.3940
# Epoch: 11/20...  Loss: 0.3634
# Epoch: 11/20...  Loss: 0.3796
# Epoch: 11/20...  Loss: 0.3628
# Epoch: 11/20...  Loss: 0.3624
# Epoch: 11/20...  Loss: 0.3888
# Epoch: 11/20...  Loss: 0.3684
# Epoch: 11/20...  Loss: 0.3948
# Epoch: 11/20...  Loss: 0.3830
# Epoch: 11/20...  Loss: 0.3622
# Epoch: 11/20...  Loss: 0.3796
# Epoch: 11/20...  Loss: 0.3768
# Epoch: 11/20...  Loss: 0.3574
# Epoch: 11/20...  Loss: 0.3318
# Epoch: 11/20...  Loss: 0.3680
# Epoch: 11/20...  Loss: 0.3901
# Epoch: 11/20...  Loss: 0.3819
# Epoch: 12/20...  Loss: 0.0209
# Epoch: 12/20...  Loss: 0.3384
# Epoch: 12/20...  Loss: 0.3857
# Epoch: 12/20...  Loss: 0.3471
# Epoch: 12/20...  Loss: 0.3742
# Epoch: 12/20...  Loss: 0.3541
# Epoch: 12/20...  Loss: 0.3515
# Epoch: 12/20...  Loss: 0.3585
# Epoch: 12/20...  Loss: 0.3827
# Epoch: 12/20...  Loss: 0.3296
# Epoch: 12/20...  Loss: 0.3590
# Epoch: 12/20...  Loss: 0.3797
# Epoch: 12/20...  Loss: 0.3412
# Epoch: 12/20...  Loss: 0.3449
# Epoch: 12/20...  Loss: 0.3795
# Epoch: 12/20...  Loss: 0.3581
# Epoch: 12/20...  Loss: 0.3736
# Epoch: 12/20...  Loss: 0.3562
# Epoch: 12/20...  Loss: 0.3636
# Epoch: 12/20...  Loss: 0.3661
# Epoch: 12/20...  Loss: 0.3694
# Epoch: 12/20...  Loss: 0.3533
# Epoch: 12/20...  Loss: 0.3329
# Epoch: 12/20...  Loss: 0.3653
# Epoch: 13/20...  Loss: 0.1884
# Epoch: 13/20...  Loss: 0.3540
# Epoch: 13/20...  Loss: 0.3334
# Epoch: 13/20...  Loss: 0.3560
# Epoch: 13/20...  Loss: 0.3644
# Epoch: 13/20...  Loss: 0.3388
# Epoch: 13/20...  Loss: 0.3818
# Epoch: 13/20...  Loss: 0.3326
# Epoch: 13/20...  Loss: 0.3380
# Epoch: 13/20...  Loss: 0.3771
# Epoch: 13/20...  Loss: 0.3406
# Epoch: 13/20...  Loss: 0.3460
# Epoch: 13/20...  Loss: 0.3214
# Epoch: 13/20...  Loss: 0.3634
# Epoch: 13/20...  Loss: 0.3531
# Epoch: 13/20...  Loss: 0.3607
# Epoch: 13/20...  Loss: 0.3589
# Epoch: 13/20...  Loss: 0.3541
# Epoch: 13/20...  Loss: 0.3769
# Epoch: 13/20...  Loss: 0.3451
# Epoch: 13/20...  Loss: 0.3514
# Epoch: 13/20...  Loss: 0.3382
# Epoch: 13/20...  Loss: 0.3201
# Epoch: 14/20...  Loss: 0.0491
# Epoch: 14/20...  Loss: 0.3185
# Epoch: 14/20...  Loss: 0.3467
# Epoch: 14/20...  Loss: 0.3386
# Epoch: 14/20...  Loss: 0.3291
# Epoch: 14/20...  Loss: 0.3466
# Epoch: 14/20...  Loss: 0.3366
# Epoch: 14/20...  Loss: 0.3583
# Epoch: 14/20...  Loss: 0.3405
# Epoch: 14/20...  Loss: 0.3407
# Epoch: 14/20...  Loss: 0.3358
# Epoch: 14/20...  Loss: 0.3375
# Epoch: 14/20...  Loss: 0.3339
# Epoch: 14/20...  Loss: 0.3488
# Epoch: 14/20...  Loss: 0.3096
# Epoch: 14/20...  Loss: 0.3509
# Epoch: 14/20...  Loss: 0.3278
# Epoch: 14/20...  Loss: 0.3516
# Epoch: 14/20...  Loss: 0.3193
# Epoch: 14/20...  Loss: 0.3609
# Epoch: 14/20...  Loss: 0.3136
# Epoch: 14/20...  Loss: 0.3423
# Epoch: 14/20...  Loss: 0.3567
# Epoch: 14/20...  Loss: 0.3447
# Epoch: 15/20...  Loss: 0.2339
# Epoch: 15/20...  Loss: 0.3389
# Epoch: 15/20...  Loss: 0.3383
# Epoch: 15/20...  Loss: 0.3533
# Epoch: 15/20...  Loss: 0.3314
# Epoch: 15/20...  Loss: 0.3353
# Epoch: 15/20...  Loss: 0.3099
# Epoch: 15/20...  Loss: 0.3275
# Epoch: 15/20...  Loss: 0.3589
# Epoch: 15/20...  Loss: 0.3204
# Epoch: 15/20...  Loss: 0.3172
# Epoch: 15/20...  Loss: 0.3439
# Epoch: 15/20...  Loss: 0.3231
# Epoch: 15/20...  Loss: 0.3402
# Epoch: 15/20...  Loss: 0.3108
# Epoch: 15/20...  Loss: 0.3338
# Epoch: 15/20...  Loss: 0.3360
# Epoch: 15/20...  Loss: 0.3215
# Epoch: 15/20...  Loss: 0.3209
# Epoch: 15/20...  Loss: 0.3244
# Epoch: 15/20...  Loss: 0.3247
# Epoch: 15/20...  Loss: 0.3198
# Epoch: 15/20...  Loss: 0.3139
# Epoch: 16/20...  Loss: 0.0744
# Epoch: 16/20...  Loss: 0.3642
# Epoch: 16/20...  Loss: 0.3309
# Epoch: 16/20...  Loss: 0.3182
# Epoch: 16/20...  Loss: 0.3221
# Epoch: 16/20...  Loss: 0.3375
# Epoch: 16/20...  Loss: 0.3211
# Epoch: 16/20...  Loss: 0.3170
# Epoch: 16/20...  Loss: 0.3340
# Epoch: 16/20...  Loss: 0.3317
# Epoch: 16/20...  Loss: 0.3344
# Epoch: 16/20...  Loss: 0.3334
# Epoch: 16/20...  Loss: 0.3011
# Epoch: 16/20...  Loss: 0.3099
# Epoch: 16/20...  Loss: 0.3384
# Epoch: 16/20...  Loss: 0.3264
# Epoch: 16/20...  Loss: 0.3211
# Epoch: 16/20...  Loss: 0.3250
# Epoch: 16/20...  Loss: 0.3173
# Epoch: 16/20...  Loss: 0.2941
# Epoch: 16/20...  Loss: 0.3061
# Epoch: 16/20...  Loss: 0.2927
# Epoch: 16/20...  Loss: 0.3193
# Epoch: 16/20...  Loss: 0.2983
# Epoch: 17/20...  Loss: 0.2452
# Epoch: 17/20...  Loss: 0.3212
# Epoch: 17/20...  Loss: 0.3188
# Epoch: 17/20...  Loss: 0.3107
# Epoch: 17/20...  Loss: 0.3436
# Epoch: 17/20...  Loss: 0.3310
# Epoch: 17/20...  Loss: 0.3053
# Epoch: 17/20...  Loss: 0.2924
# Epoch: 17/20...  Loss: 0.3160
# Epoch: 17/20...  Loss: 0.3190
# Epoch: 17/20...  Loss: 0.3070
# Epoch: 17/20...  Loss: 0.3095
# Epoch: 17/20...  Loss: 0.3070
# Epoch: 17/20...  Loss: 0.3143
# Epoch: 17/20...  Loss: 0.3060
# Epoch: 17/20...  Loss: 0.3295
# Epoch: 17/20...  Loss: 0.3109
# Epoch: 17/20...  Loss: 0.3247
# Epoch: 17/20...  Loss: 0.3120
# Epoch: 17/20...  Loss: 0.3302
# Epoch: 17/20...  Loss: 0.3059
# Epoch: 17/20...  Loss: 0.3170
# Epoch: 17/20...  Loss: 0.3125
# Epoch: 18/20...  Loss: 0.1085
# Epoch: 18/20...  Loss: 0.3324
# Epoch: 18/20...  Loss: 0.3117
# Epoch: 18/20...  Loss: 0.3129
# Epoch: 18/20...  Loss: 0.3061
# Epoch: 18/20...  Loss: 0.2923
# Epoch: 18/20...  Loss: 0.2921
# Epoch: 18/20...  Loss: 0.2777
# Epoch: 18/20...  Loss: 0.3024
# Epoch: 18/20...  Loss: 0.3238
# Epoch: 18/20...  Loss: 0.2964
# Epoch: 18/20...  Loss: 0.3244
# Epoch: 18/20...  Loss: 0.2890
# Epoch: 18/20...  Loss: 0.3096
# Epoch: 18/20...  Loss: 0.3230
# Epoch: 18/20...  Loss: 0.3071
# Epoch: 18/20...  Loss: 0.2893
# Epoch: 18/20...  Loss: 0.3170
# Epoch: 18/20...  Loss: 0.2964
# Epoch: 18/20...  Loss: 0.3141
# Epoch: 18/20...  Loss: 0.3114
# Epoch: 18/20...  Loss: 0.3177
# Epoch: 18/20...  Loss: 0.2883
# Epoch: 18/20...  Loss: 0.3226
# Epoch: 19/20...  Loss: 0.2713
# Epoch: 19/20...  Loss: 0.2961
# Epoch: 19/20...  Loss: 0.2798
# Epoch: 19/20...  Loss: 0.3112
# Epoch: 19/20...  Loss: 0.2786
# Epoch: 19/20...  Loss: 0.3285
# Epoch: 19/20...  Loss: 0.3241
# Epoch: 19/20...  Loss: 0.3168
# Epoch: 19/20...  Loss: 0.2904
# Epoch: 19/20...  Loss: 0.3174
# Epoch: 19/20...  Loss: 0.2738
# Epoch: 19/20...  Loss: 0.3017
# Epoch: 19/20...  Loss: 0.3164
# Epoch: 19/20...  Loss: 0.2858
# Epoch: 19/20...  Loss: 0.3101
# Epoch: 19/20...  Loss: 0.3009
# Epoch: 19/20...  Loss: 0.3035
# Epoch: 19/20...  Loss: 0.2832
# Epoch: 19/20...  Loss: 0.2727
# Epoch: 19/20...  Loss: 0.2862
# Epoch: 19/20...  Loss: 0.2974
# Epoch: 19/20...  Loss: 0.2976
# Epoch: 19/20...  Loss: 0.3392
# Epoch: 20/20...  Loss: 0.1186
# Epoch: 20/20...  Loss: 0.3039
# Epoch: 20/20...  Loss: 0.2909
# Epoch: 20/20...  Loss: 0.2915
# Epoch: 20/20...  Loss: 0.3130
# Epoch: 20/20...  Loss: 0.2610
# Epoch: 20/20...  Loss: 0.2845
# Epoch: 20/20...  Loss: 0.3036
# Epoch: 20/20...  Loss: 0.2909
# Epoch: 20/20...  Loss: 0.2906
# Epoch: 20/20...  Loss: 0.2976
# Epoch: 20/20...  Loss: 0.2922
# Epoch: 20/20...  Loss: 0.2860
# Epoch: 20/20...  Loss: 0.2784
# Epoch: 20/20...  Loss: 0.3042
# Epoch: 20/20...  Loss: 0.2873
# Epoch: 20/20...  Loss: 0.3086
# Epoch: 20/20...  Loss: 0.2852
# Epoch: 20/20...  Loss: 0.3058
# Epoch: 20/20...  Loss: 0.3036
# Epoch: 20/20...  Loss: 0.2904
# Epoch: 20/20...  Loss: 0.3111
# Epoch: 20/20...  Loss: 0.3034
# Epoch: 20/20...  Loss: 0.2856

# %%
# Test out your network!

dataiter = iter(testloader)
images, labels = dataiter.next()
img = images[0]
# Convert 2D image to 1D vector
img = img.resize_(1, 784)

# Turn off gradients to speed up this part
with torch.no_grad():
    logits = model.forward(img)

# TODO: Calculate the class probabilities (softmax) for img
ps = F.softmax(logits, dim=1)

# Plot the image and probabilities
helper.view_classify(img.resize_(1, 28, 28), ps, version='Fashion')

# %% [markdown]
# Now that your network is trained, you'll want to save it to disk so you can load it later instead of training it again. Obviously, it's impractical to train a network every time you need one. In practice, you'll train it once, save the model, then reload it for further training or making predictions. In the next part, I'll show you how to save and load trained models.
